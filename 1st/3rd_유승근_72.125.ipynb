# %% [markdown]
# ## 제 1회 D.COMpetition 참여를 환영합니다!
# 본격적인 대회 참여에 앞서 **베이스라인(baseline)** 코드를 소개합니다.
# 베이스라인 코드를 통해 대회 진행에 필요한 전체적인 감을 익힐 수 있습니다.
# 해당 코드를 바탕으로 여러분들이 배운 내용을 활용하여 우수한 실력을 뽐내보세요!
# 대회를 진행하면서 궁금하거나 도움이 필요하면 언제나 대회 운영진(**서주원([JJuOn](https://github.com/JJuOn))**, **송용우([FacerAin](https://github.com/FacerAin)))**에게 물어보시기 바랍니다 :)

# %% [markdown]
# ## 0. Prepare Environment
# 본격적인 개발에 앞서 필요한 환경을 구축합니다. 다음과 같은 순서로 구성됩니다.
# 1. 라이브러리 설치
# 2. 구글 드라이브 연결
# 3. 라이브러리 불러오기
# 4. 데이터파일 복사해서 불러오기
# 5. CUDA 세팅하기
# 6. 랜덤 시드 설정하기

# %% [markdown]
# ### 라이브러리 설치
# 필요한 라이브러리를 설치합니다.
# 노트북 환경에서는 **느낌표(!)를 이용하여 셀 명령어를 실행**시킬 수 있습니다.

# %%
# !pip install timm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting timm
#   Downloading timm-0.6.7-py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 5.1 MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.13.0+cu113)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.12.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (4.1.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.21.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2022.6.15)
# Installing collected packages: timm
# Successfully installed timm-0.6.7

# %%
# !nvidia-smi
# Out:
# Fri Aug 12 13:34:29 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Mount Google Drive
# 자신 계정의 구글 드라이브에 마운트합니다.
# 코랩이 구글 드라이브의 파일들에 접근할 수 있도록 합니다.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import Library
# 필요한 라이브러리를 불러옵니다.

# %%
import torch
import timm
import os
import random

import math

import torch.nn.functional as F
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from torch import nn, optim
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision.datasets import ImageFolder
from torchvision import transforms
from PIL import Image
from datetime import datetime

from torch.optim.lr_scheduler import _LRScheduler

# %matplotlib inline

# %% [markdown]
# ### Copy data files
# 우선 **캐글에서 다운받은 데이터 파일(data.zip, sample_submission.csv)**을 **해당 구글 드라이브 경로(MyDrive/dcompetition/)**에 올려주세요.
# **(!!중요!! 이때 data 폴더는 zip 파일로 압축해서 올려주세요!)**
#
# 그리고 데이터를 불러오기 편하도록 구글 드라이브 상의 데이터 파일들을 현재 위치로 복사하고 압축을 해제합니다.

# %%
# !cp /content/drive/MyDrive/dcompetition/data.zip .
# !cp /content/drive/MyDrive/dcompetition/sample_submission.csv .
# !unzip data.zip -d .
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: ./train/Siberian_husky/n02110185_7980.jpg
#   inflating: ./train/Siberian_husky/n02110185_8005.jpg
#   inflating: ./train/Siberian_husky/n02110185_815.jpg
#   inflating: ./train/Siberian_husky/n02110185_8154.jpg
#   inflating: ./train/Siberian_husky/n02110185_8162.jpg
#   inflating: ./train/Siberian_husky/n02110185_8327.jpg
#   inflating: ./train/Siberian_husky/n02110185_8360.jpg
#   inflating: ./train/Siberian_husky/n02110185_8397.jpg
#   inflating: ./train/Siberian_husky/n02110185_8564.jpg
#   inflating: ./train/Siberian_husky/n02110185_8600.jpg
#   inflating: ./train/Siberian_husky/n02110185_8708.jpg
#   inflating: ./test/2383.jpg
#   inflating: ./test/2384.jpg
#   inflating: ./test/2385.jpg
#   inflating: ./test/2386.jpg
#   inflating: ./test/2387.jpg
#   inflating: ./test/2388.jpg
#   inflating: ./test/2389.jpg
#   inflating: ./test/2390.jpg
#   inflating: ./test/2391.jpg
#   inflating: ./test/2392.jpg
#   inflating: ./test/2393.jpg
#   inflating: ./test/2394.jpg
#   inflating: ./test/2395.jpg
#   inflating: ./test/2396.jpg
#   inflating: ./test/2397.jpg
#   inflating: ./test/2398.jpg
#   inflating: ./test/2399.jpg

# %% [markdown]
# ### Cuda Setting
# 가용한 GPU가 있다면 **GPU 자원을 활용**할 수 있도록 CUDA를 활성화합니다.

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %% [markdown]
# ### Set Random Seed
# 모델을 구동할 때마다 다른 결과가 나오는 것을 방지하기 위해
# **랜덤 시드 값을 고정**합니다.

# %%
torch.manual_seed(0)
torch.cuda.manual_seed(0)
np.random.seed(0)
random.seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ## 1. 데이터 전처리하기
# 학습에 필요한 데이터를 전처리해봅시다! 데이터셋을 정의하고, 정제하는 과정을 거칩니다. 순서는 다음과 같습니다.
# 1. Define Dataset Class
# 2. Define Data Transform
# 3. Make Train/Valid Dataset
# 4. Make DataLoader

# %% [markdown]
# ### Define Dataset Class
# Pytorch에서는 사용자가 편하게 데이터셋을 관리할 수 있도록 Dataset 클래스를 제공합니다.
# **Dataset 클래스를 상속받아 사용자 정의 Dataset 클래스를 만들 수 있습니다.**
# 자세한 내용은 [파이토치 공식 레퍼런스 문서](https://tutorials.pytorch.kr/beginner/basics/data_tutorial.html)를 참고해주세요.

# %%
class CustomSubset(Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.indices = self.subset.indices
        self.transform = transform

    def __getitem__(self, idx):
        img, label = self.subset[idx]
        if self.transform is not None:
            img = self.transform(img)
        return img, label

    def __len__(self):
        return len(self.subset)


class TestDataset(Dataset):
    def __init__(self, root='./test', transform=None):
        self.root = root
        self.data = os.listdir(self.root)
        self.data = sorted(self.data)
        self.transform = transform

    def __getitem__(self, idx):
        img = Image.open(os.path.join(self.root, self.data[idx]))
        if self.transform is not None:
            img = self.transform(img)
        return img
    
    def __len__(self):
        return len(self.data)

# %% [markdown]
# ### Define Data Transform
# torchvision.transforms 모듈을 통해 편리하게 데이터 **transforming과 augmentation**을 정의할 수 있습니다.
# 자세한 내용은 관련 [공식 도큐먼트 문서](https://pytorch.org/vision/stable/transforms.html)를 참고해주세요.

# %%
from torchvision.transforms.transforms import RandomRotation
transform = {
    'train': transforms.Compose([transforms.Resize((256,256)),
                                 transforms.RandomResizedCrop((224,224)),
                                 transforms.ColorJitter(brightness=(0.8,1.3), contrast=0.5, saturation=0.5), #.밝기,대비,채도 변경
                                 transforms.RandomRotation(15),
                                 transforms.RandomHorizontalFlip(),
                                 transforms.ToTensor(),
                                 transforms.Normalize([0.476, 0.440, 0.384], [0.229, 0.224, 0.220]), #dataset 정규화값
                                 transforms.RandomErasing() #무작위 구역 삭제
                                 ]),
             
    'valid': transforms.Compose([transforms.Resize((256,256)),
                                 transforms.CenterCrop((224,224)),
                                 transforms.ToTensor(),
                                 transforms.Normalize([0.476, 0.440, 0.384], [0.229, 0.224, 0.220])
                                 ]),
}

# %% [markdown]
# ### Make Train/Valid Dataset
# 앞서 정의한 Dataset Class와 Transforms를 활용하여 Train, Valid 데이터셋을 만듭니다.
# 이때 Train/Valid 비율은 8:2로 하였습니다.

# %%
all_data = ImageFolder(root='./train')

train_ratio = 0.8
train_data_len = int(len(all_data) * train_ratio)
valid_data_len = len(all_data) - train_data_len
train_data, valid_data = random_split(all_data, [train_data_len, valid_data_len])

train_data = CustomSubset(train_data, transform['train'])
valid_data = CustomSubset(valid_data, transform['valid'])

# %% [markdown]
# ### Make DataLoader
# Pytorch에서는 데이터셋 안의 샘플들에 쉽게 접근할 수 있도록 **순회 가능한 객체(iterable)인 DataLoader를 제공**합니다.
# 이를 통해 모델 학습간 보다 쉽게 데이터 샘플에 접근하여 사용할 수 있습니다.
# 또한 이때 데이터셋의 배치 크기를 정의하거나 무작위 섞기(shuffle) 유무를 설정할 수 있습니다.

# %%
batch_size = 128
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True,drop_last=True)
valid_loader = DataLoader(valid_data, batch_size=batch_size, shuffle=False,drop_last=True)

# %% [markdown]
# ## EDA (Exploratory Data Analysis)
# 본격적으로 모델을 만들기 전에, **다루고자 하는 데이터가 어떤 특징을 가졌는지 탐색하고 이해하는 것은 매우 중요합니다.**
# 이 과정을 **탐색적 데이터 분석(EDA)**라고 합니다.
# 이번 베이스라인 코드에서는 이미지가 어떻게 생겼는지, 개수는 어떠한지 간단하게 파악해보도록 합니다.
# 실제 대회에서는 반드시 EDA를 꼼꼼히 진행하여 데이터를 확실히 이해하고 진행할 수 있도록 합시다!

# %% [markdown]
# ### Train/Dev 데이터 개수

# %%
print("Train/Valid Data Size: " + str(len(all_data)))
print("Train Data Size: " + str(train_data_len))
print("Valid Data Size: " + str(valid_data_len))
# Out:
# Train/Valid Data Size: 18180
# Train Data Size: 14544
# Valid Data Size: 3636

# %% [markdown]
# ### Class 개수

# %%
print("Number of Classes: " + str(len(all_data.classes)))
print(all_data.classes[:10])
# Out:
# Number of Classes: 120
# ['Affenpinscher', 'Afghan_hound', 'African_hunting_dog', 'Airedale', 'American_staffordshire_terrier', 'Appenzeller', 'Australian_terrier', 'Basenji', 'Basset', 'Beagle']

# %% [markdown]
# ### Class 별 Sample 개수

# %%
items = all_data.class_to_idx.items()
idx2class = {v:k for k, v in items}
count_dict = {k:0 for k, v in items}
for item in all_data:
    label = item[1]
    count_dict[idx2class[label]] += 1

print(count_dict)
plt.bar(np.arange(len(count_dict)), count_dict.values())
# Out:
# {'Affenpinscher': 130, 'Afghan_hound': 219, 'African_hunting_dog': 149, 'Airedale': 182, 'American_staffordshire_terrier': 144, 'Appenzeller': 131, 'Australian_terrier': 176, 'Basenji': 189, 'Basset': 155, 'Beagle': 175, 'Bedlington_terrier': 162, 'Bernese_mountain_dog': 198, 'Black-and-tan_coonhound': 139, 'Blenheim_spaniel': 168, 'Bloodhound': 167, 'Bluetick': 151, 'Border_collie': 130, 'Border_terrier': 152, 'Borzoi': 131, 'Boston_bull': 162, 'Bouvier_des_flandres': 130, 'Boxer': 131, 'Brabancon_griffon': 133, 'Briard': 132, 'Brittany_spaniel': 132, 'Bull_mastiff': 136, 'Cairn': 177, 'Cardigan': 135, 'Chesapeake_bay_retriever': 147, 'Chihuahua': 132, 'Chow': 176, 'Clumber': 130, 'Cocker_spaniel': 139, 'Collie': 133, 'Curly-coated_retriever': 131, 'Dandie_dinmont': 160, 'Dhole': 130, 'Dingo': 136, 'Doberman': 130, 'English_foxhound': 137, 'English_setter': 141, 'English_springer': 139, 'Entlebucher': 182, 'Eskimo_dog': 130, 'Flat-coated_retriever': 132, 'French_bulldog': 139, 'German_shepherd': 132, 'German_short-haired_pointer': 132, 'Giant_schnauzer': 137, 'Golden_retriever': 130, 'Gordon_setter': 133, 'Great_dane': 136, 'Great_pyrenees': 193, 'Greater_swiss_mountain_dog': 148, 'Groenendael': 130, 'Ibizan_hound': 168, 'Irish_setter': 135, 'Irish_terrier': 149, 'Irish_water_spaniel': 130, 'Irish_wolfhound': 198, 'Italian_greyhound': 162, 'Japanese_spaniel': 165, 'Keeshond': 138, 'Kelpie': 133, 'Kerry_blue_terrier': 159, 'Komondor': 134, 'Kuvasz': 130, 'Labrador_retriever': 151, 'Lakeland_terrier': 177, 'Leonberg': 190, 'Lhasa': 166, 'Malamute': 158, 'Malinois': 130, 'Maltese_dog': 232, 'Mexican_hairless': 135, 'Miniature_pinscher': 164, 'Miniature_poodle': 135, 'Miniature_schnauzer': 134, 'Newfoundland': 175, 'Norfolk_terrier': 152, 'Norwegian_elkhound': 176, 'Norwich_terrier': 165, 'Old_english_sheepdog': 149, 'Otterhound': 131, 'Papillon': 176, 'Pekinese': 129, 'Pembroke': 161, 'Pomeranian': 199, 'Pug': 180, 'Redbone': 128, 'Rhodesian_ridgeback': 152, 'Rottweiler': 132, 'Saint_bernard': 150, 'Saluki': 180, 'Samoyed': 198, 'Schipperke': 134, 'Scotch_terrier': 138, 'Scottish_deerhound': 212, 'Sealyham_terrier': 182, 'Shetland_sheepdog': 137, 'Shih-tzu': 194, 'Siberian_husky': 172, 'Silky_terrier': 163, 'Soft-coated_wheaten_terrier': 136, 'Staffordshire_bullterrier': 135, 'Standard_poodle': 139, 'Standard_schnauzer': 135, 'Sussex_spaniel': 131, 'Tibetan_mastiff': 132, 'Tibetan_terrier': 186, 'Toy_poodle': 131, 'Toy_terrier': 152, 'Vizsla': 134, 'Walker_hound': 133, 'Weimaraner': 140, 'Welsh_springer_spaniel': 130, 'West_highland_white_terrier': 149, 'Whippet': 167, 'Wire-haired_fox_terrier': 137, 'Yorkshire_terrier': 144}
# <BarContainer object of 120 artists>

# %% [markdown]
# ### 학습데이터 시각화

# %%
fig = plt.figure(figsize=(16, 16))
axes = []
idx_to_visualize = random.sample(list(range(len(all_data))), 5)
for i,idx in enumerate(idx_to_visualize):
    image, label = all_data[idx]
    axes.append(fig.add_subplot(1, 5, i+1))
    axes[i].set_title(idx2class[label])
    axes[i].imshow(image)
plt.show()

# %% [markdown]
# ### 학습데이터 전처리 결과

# %%
fig = plt.figure(figsize=(16, 16))
axes = []
idx_to_visualize = random.sample(list(range(len(train_data))), 5)
for i,idx in enumerate(idx_to_visualize):
    image, label = train_data[idx]
    axes.append(fig.add_subplot(1, 5, i+1))
    axes[i].set_title(idx2class[label])
    axes[i].imshow(image.permute(1,2,0))
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Make Model
#  **model - efficientnet_b0**
#
#  **optimizer - AdamW**

# %%
# for checking the number of parameters
# do not modify below
def param_check(model):
    total = 0
    for param in model.parameters():
        total += torch.numel(param)
    return total < 15000000

# %%
model = timm.create_model('efficientnet_b0', pretrained=False, num_classes=120)
# check the number of parameters
assert param_check(model)

optimizer = optim.AdamW(model.parameters(), lr=0, weight_decay=0.1)
criterion = nn.CrossEntropyLoss()

model = model.to(device)
criterion = criterion.to(device)

print(model)
# Out:
# EfficientNet(
#   (conv_stem): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNormAct2d(
#     32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity()
#     (act): SiLU(inplace=True)
#   )
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): DepthwiseSeparableConv(
#         (conv_dw): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn1): BatchNormAct2d(
#           32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pw): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNormAct2d(
#           16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (1): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (bn2): BatchNormAct2d(
#           96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (bn2): BatchNormAct2d(
#           144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (2): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#         (bn2): BatchNormAct2d(
#           144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#         (bn2): BatchNormAct2d(
#           240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (3): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#         (bn2): BatchNormAct2d(
#           240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#         (bn2): BatchNormAct2d(
#           480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#         (bn2): BatchNormAct2d(
#           480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (4): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#         (bn2): BatchNormAct2d(
#           480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#         (bn2): BatchNormAct2d(
#           672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#         (bn2): BatchNormAct2d(
#           672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (5): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#         (bn2): BatchNormAct2d(
#           672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#     (6): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (conv_dw): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#         (bn2): BatchNormAct2d(
#           1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): SiLU(inplace=True)
#         )
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNormAct2d(
#           320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#           (drop): Identity()
#           (act): Identity()
#         )
#         (drop_path): Identity()
#       )
#     )
#   )
#   (conv_head): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn2): BatchNormAct2d(
#     1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#     (drop): Identity()
#     (act): SiLU(inplace=True)
#   )
#   (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#   (classifier): Linear(in_features=1280, out_features=120, bias=True)
# )

# %% [markdown]
# ## Learning scheduler
#  **Custom CosineAnnealingWarmUpRestarts**
#
# https://github.com/gaussian37/pytorch_deep_learning_models/blob/master/cosine_annealing_with_warmup/cosine_annealing_with_warmup.py

# %%
class CosineAnnealingWarmUpRestarts(_LRScheduler):
    def __init__(self, optimizer, T_0, T_mult=1, eta_max=0.1, T_up=0, gamma=1., last_epoch=-1):
        if T_0 <= 0 or not isinstance(T_0, int):
            raise ValueError("Expected positive integer T_0, but got {}".format(T_0))
        if T_mult < 1 or not isinstance(T_mult, int):
            raise ValueError("Expected integer T_mult >= 1, but got {}".format(T_mult))
        if T_up < 0 or not isinstance(T_up, int):
            raise ValueError("Expected positive integer T_up, but got {}".format(T_up))
        self.T_0 = T_0
        self.T_mult = T_mult
        self.base_eta_max = eta_max
        self.eta_max = eta_max
        self.T_up = T_up
        self.T_i = T_0
        self.gamma = gamma
        self.cycle = 0
        self.T_cur = last_epoch
        super(CosineAnnealingWarmUpRestarts, self).__init__(optimizer, last_epoch)
    
    def get_lr(self):
        if self.T_cur == -1:
            return self.base_lrs
        elif self.T_cur < self.T_up:
            return [(self.eta_max - base_lr)*self.T_cur / self.T_up + base_lr for base_lr in self.base_lrs]
        else:
            return [base_lr + (self.eta_max - base_lr) * (1 + math.cos(math.pi * (self.T_cur-self.T_up) / (self.T_i - self.T_up))) / 2
                    for base_lr in self.base_lrs]

    def step(self, epoch=None):
        if epoch is None:
            epoch = self.last_epoch + 1
            self.T_cur = self.T_cur + 1
            if self.T_cur >= self.T_i:
                self.cycle += 1
                self.T_cur = self.T_cur - self.T_i
                self.T_i = (self.T_i - self.T_up) * self.T_mult + self.T_up
        else:
            if epoch >= self.T_0:
                if self.T_mult == 1:
                    self.T_cur = epoch % self.T_0
                    self.cycle = epoch // self.T_0
                else:
                    n = int(math.log((epoch / self.T_0 * (self.T_mult - 1) + 1), self.T_mult))
                    self.cycle = n
                    self.T_cur = epoch - self.T_0 * (self.T_mult ** n - 1) / (self.T_mult - 1)
                    self.T_i = self.T_0 * self.T_mult ** (n)
            else:
                self.T_i = self.T_0
                self.T_cur = epoch
                
        self.eta_max = self.base_eta_max * (self.gamma**self.cycle)
        self.last_epoch = math.floor(epoch)
        for param_group, lr in zip(self.optimizer.param_groups, self.get_lr()):
            param_group['lr'] = lr

# %%
#50epoch 주기, max learning rate 0.005, warmup start 5epoch, max값 감소없음
scheduler = CosineAnnealingWarmUpRestarts(optimizer, T_0=50, T_mult=1, eta_max=0.005,  T_up=5, gamma=1.0)

# %% [markdown]
# ## 학습 진행하기
# 모델 학습(train)과 검증(validation)을 진행해봅시다.

# %%
def train(model, criterion, optimizer, train_loader, valid_loader, num_epochs, device, print_every=10):
    train_losses = []
    train_accs = []
    valid_losses = []
    valid_accs = []
    best_acc = -np.inf
    start_time = datetime.now()
    try:
        for epoch in range(num_epochs):
            train_loss = 0
            train_acc = 0
            processed = 0
            model.train()
            # training step
            for i, (data, label) in enumerate(train_loader):
                data, label = data.to(device), label.to(device)
                pred = model(data)
                loss = criterion(pred, label)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                train_loss += loss.item() * data.size(0)
                train_acc += torch.sum(pred.argmax(1) == label).item()
                processed += data.size(0)
                if (i % print_every == 0) or (i == len(train_loader) - 1):
                    print(f'Epoch [{epoch}/{num_epochs - 1}]({(i + 1) / len(train_loader) * 100:.2f}%)\ttrain loss: {train_loss / processed:.4f}\ttrain acc: {train_acc / processed * 100:.4f}%\ttime elapsed: {datetime.now() - start_time}')
            train_losses.append(train_loss / processed)
            train_accs.append(train_acc / processed)
            print("="*90)

            scheduler.step()

            # validation step
            valid_loss = 0
            valid_acc = 0
            processed = 0
            model.eval()
            with torch.no_grad():
                for i, (data, label) in enumerate(valid_loader):
                    data, label = data.to(device), label.to(device)
                    pred = model(data)
                    loss = criterion(pred, label)
                    valid_loss += loss.item() * data.size(0)
                    valid_acc += torch.sum(pred.argmax(1) == label).item()
                    processed += data.size(0)
                    if (i % print_every == 0) or (i == len(valid_loader) - 1):
                        print(f'Epoch [{epoch}/{num_epochs - 1}]({(i + 1) / len(valid_loader) * 100:.2f}%)\tvalid loss: {valid_loss / processed:.4f}\tvalid acc: {valid_acc / processed * 100:.4f}%\ttime elapsed: {datetime.now() - start_time}')
                if valid_acc / processed > best_acc:
                    best_acc = valid_acc / processed
                    torch.save(model.state_dict(), 'model_best.pth')
                
                torch.save(model.state_dict(), 'model_last.pth')
                valid_losses.append(valid_loss / processed)
                valid_accs.append(valid_acc / processed)
            print("="*90,"lr = ",optimizer.param_groups[0]['lr'])
        return train_losses, train_accs, valid_losses, valid_accs
    except KeyboardInterrupt:
        return train_losses, train_accs, valid_losses, valid_accs

# %%
train_losses, train_accs, valid_losses, valid_accs = train(model, criterion, optimizer, train_loader, valid_loader, num_epochs=300, device=device)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#
# Epoch [299/299](71.68%)	train loss: 0.5842	train acc: 84.0085%	time elapsed: 15:21:34.992029
# Epoch [299/299](80.53%)	train loss: 0.5790	train acc: 84.1003%	time elapsed: 15:21:50.883705
# Epoch [299/299](89.38%)	train loss: 0.5782	train acc: 84.0888%	time elapsed: 15:22:06.700765
# Epoch [299/299](98.23%)	train loss: 0.5770	train acc: 84.1498%	time elapsed: 15:22:22.441378
# Epoch [299/299](100.00%)	train loss: 0.5770	train acc: 84.1814%	time elapsed: 15:22:25.736991
# ==========================================================================================
# Epoch [299/299](3.57%)	valid loss: 1.1104	valid acc: 68.7500%	time elapsed: 15:22:26.438386
# Epoch [299/299](39.29%)	valid loss: 1.0483	valid acc: 73.2955%	time elapsed: 15:22:33.292935
# Epoch [299/299](75.00%)	valid loss: 1.0711	valid acc: 73.1771%	time elapsed: 15:22:41.182200
# Epoch [299/299](100.00%)	valid loss: 1.0663	valid acc: 73.1027%	time elapsed: 15:22:46.003122
# ========================================================================================== lr =  0.0

# %%
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(range(len(train_losses)), train_losses, label='train_loss', color='red')
plt.plot(range(len(valid_losses)), valid_losses, label='valid_loss', color='blue')
plt.legend()
plt.grid()
plt.show()

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.plot(range(len(train_accs)), train_accs, label='train_acc', color='red')
plt.plot(range(len(valid_accs)), valid_accs, label='valid_acc', color='blue')
plt.legend()
plt.grid()
plt.show()

# %%
max(valid_accs)
# Out:
# 0.7354910714285714

# %%
max(train_accs)
# Out:
# 0.8418141592920354

# %% [markdown]
# 학습 metric을 통해 모델의 학습이 원활하게 이루어졌는지, 과적합(Overfitting)은 없었는지 평가해봅시다.
# 부족한 부분이 있다면 어디서 어떻게 개선할 수 있을까요?

# %% [markdown]
# ## Test Model
# 학습한 모델을 Test 데이터셋으로 구동해봅시다.
# 실행 결과는 submission.csv에 담아 Kaggle에 제출해주세요.

# %%
model.load_state_dict(torch.load('model_best.pth'))
model = model.to(device)

# %% [markdown]
# valid data 오답, 정답률

# %%
items = all_data.class_to_idx.items()
idx2class = {v:k for k, v in items}
count_dict = {k:0 for k, v in items}
correct_dict = {k:0 for k, v in items}

correct = 0
not_correct = 0
model.eval()
with torch.no_grad():
    for i, (data, label) in enumerate(valid_loader):
        data, label = data.to(device), label.to(device)
        pred = model(data)
        for i in range(64):
          if all_data.classes[pred[i].max(dim=0)[1]] == all_data.classes[label[i]]:
            correct += 1
            correct_dict[all_data.classes[label[i]]] += 1
          else:
            not_correct += 1
            print("(predict)",all_data.classes[pred[i].max(dim=0)[1]],"->","(correct)",all_data.classes[label[i]])
          count_dict[all_data.classes[label[i]]] += 1

print("correct = ",correct," / not_correct = ",not_correct)
print(count_dict)
print(correct_dict)
for i in range(120):
  count_dict[all_data.classes[i]] = correct_dict[all_data.classes[i]] / count_dict[all_data.classes[i]]
print(count_dict)
plt.bar(np.arange(len(count_dict)), count_dict.values())
# Out:
# (predict) Miniature_schnauzer -> (correct) Standard_schnauzer
# (predict) Appenzeller -> (correct) Bernese_mountain_dog
# (predict) Shih-tzu -> (correct) Lhasa
# (predict) Miniature_pinscher -> (correct) German_shepherd
# (predict) Great_dane -> (correct) Mexican_hairless
# (predict) German_shepherd -> (correct) Siberian_husky
# (predict) Lhasa -> (correct) Tibetan_terrier
# (predict) Lhasa -> (correct) Sealyham_terrier
# (predict) Norwich_terrier -> (correct) Cairn
# (predict) Great_pyrenees -> (correct) Clumber
# (predict) American_staffordshire_terrier -> (correct) Staffordshire_bullterrier
# (predict) Soft-coated_wheaten_terrier -> (correct) Tibetan_terrier
# (predict) Scottish_deerhound -> (correct) Whippet
# (predict) Cairn -> (correct) Norfolk_terrier
# (predict) Border_terrier -> (correct) Soft-coated_wheaten_terrier
# (predict) Norfolk_terrier -> (correct) Cairn
# (predict) Shetland_sheepdog -> (correct) Collie
# (predict) Whippet -> (correct) Pug
# (predict) Appenzeller -> (correct) Basenji
# (predict) Labrador_retriever -> (correct) Staffordshire_bullterrier
# (predict) Black-and-tan_coonhound -> (correct) Miniature_pinscher
# (predict) Pekinese -> (correct) Brabancon_griffon
# (predict) Weimaraner -> (correct) Great_dane
# (predict) Cairn -> (correct) Border_terrier
# (predict) Curly-coated_retriever -> (correct) Standard_poodle
# (predict) Italian_greyhound -> (correct) Whippet
# (predict) Yorkshire_terrier -> (correct) Tibetan_terrier
# (predict) Lakeland_terrier -> (correct) Wire-haired_fox_terrier
# (predict) Malamute -> (correct) Eskimo_dog
# (predict) Standard_schnauzer -> (correct) Miniature_schnauzer
# (predict) Great_pyrenees -> (correct) Saint_bernard
# (predict) Doberman -> (correct) Mexican_hairless
# (predict) Basenji -> (correct) Rhodesian_ridgeback
# (predict) Miniature_pinscher -> (correct) Schipperke
# (predict) Afghan_hound -> (correct) Briard
# (predict) Giant_schnauzer -> (correct) Standard_poodle
# (predict) Sealyham_terrier -> (correct) Lakeland_terrier
# (predict) Norwich_terrier -> (correct) Norfolk_terrier
# (predict) Greater_swiss_mountain_dog -> (correct) Bernese_mountain_dog
# (predict) Yorkshire_terrier -> (correct) Australian_terrier
# (predict) Kerry_blue_terrier -> (correct) Bouvier_des_flandres
# (predict) Curly-coated_retriever -> (correct) Bouvier_des_flandres
# (predict) West_highland_white_terrier -> (correct) Norfolk_terrier
# (predict) Siberian_husky -> (correct) Malamute
# (predict) French_bulldog -> (correct) Chihuahua
# (predict) Yorkshire_terrier -> (correct) Australian_terrier
# (predict) Eskimo_dog -> (correct) Siberian_husky
# (predict) Bouvier_des_flandres -> (correct) Giant_schnauzer
# (predict) Lakeland_terrier -> (correct) Toy_poodle
# (predict) Walker_hound -> (correct) English_foxhound
# (predict) American_staffordshire_terrier -> (correct) Staffordshire_bullterrier
# (predict) Cairn -> (correct) Lhasa
# (predict) Silky_terrier -> (correct) Yorkshire_terrier
# (predict) Collie -> (correct) Cardigan
# (predict) Dandie_dinmont -> (correct) Silky_terrier
# (predict) Blenheim_spaniel -> (correct) Brittany_spaniel
# (predict) Great_dane -> (correct) Labrador_retriever
# (predict) Basenji -> (correct) Dingo
# (predict) Great_pyrenees -> (correct) Golden_retriever
# (predict) Weimaraner -> (correct) Doberman
# (predict) Appenzeller -> (correct) Bernese_mountain_dog
# (predict) Labrador_retriever -> (correct) Beagle
# (predict) Miniature_pinscher -> (correct) Kelpie
# (predict) American_staffordshire_terrier -> (correct) Whippet
# (predict) Standard_schnauzer -> (correct) Dandie_dinmont
# (predict) Doberman -> (correct) Mexican_hairless
# (predict) Kerry_blue_terrier -> (correct) Standard_schnauzer
# (predict) Tibetan_mastiff -> (correct) Great_pyrenees
# (predict) Miniature_pinscher -> (correct) Toy_terrier
# (predict) Walker_hound -> (correct) Basset
# (predict) Papillon -> (correct) Bernese_mountain_dog
# (predict) Siberian_husky -> (correct) Eskimo_dog
# (predict) Walker_hound -> (correct) Beagle
# (predict) Airedale -> (correct) Otterhound
# (predict) Samoyed -> (correct) Great_pyrenees
# (predict) Great_pyrenees -> (correct) Kuvasz
# (predict) American_staffordshire_terrier -> (correct) Vizsla
# (predict) American_staffordshire_terrier -> (correct) Bull_mastiff
# (predict) Otterhound -> (correct) Irish_terrier
# (predict) Schipperke -> (correct) Groenendael
# (predict) Walker_hound -> (correct) English_foxhound
# (predict) Boston_bull -> (correct) Toy_terrier
# (predict) Tibetan_terrier -> (correct) Affenpinscher
# (predict) Doberman -> (correct) Black-and-tan_coonhound
# (predict) Entlebucher -> (correct) Appenzeller
# (predict) Walker_hound -> (correct) English_foxhound
# (predict) Whippet -> (correct) Ibizan_hound
# (predict) Labrador_retriever -> (correct) Great_dane
# (predict) Miniature_poodle -> (correct) Standard_poodle
# (predict) American_staffordshire_terrier -> (correct) Great_dane
# (predict) Cairn -> (correct) Shih-tzu
# (predict) Newfoundland -> (correct) Giant_schnauzer
# (predict) Appenzeller -> (correct) Bernese_mountain_dog
# (predict) Doberman -> (correct) Miniature_pinscher
# (predict) Border_collie -> (correct) Cardigan
# (predict) Rhodesian_ridgeback -> (correct) Labrador_retriever
# (predict) Wire-haired_fox_terrier -> (correct) Otterhound
# (predict) Staffordshire_bullterrier -> (correct) American_staffordshire_terrier
# (predict) Whippet -> (correct) Leonberg
# (predict) Scotch_terrier -> (correct) Standard_schnauzer
# (predict) American_staffordshire_terrier -> (correct) Great_dane
# (predict) Miniature_schnauzer -> (correct) Sealyham_terrier
# (predict) American_staffordshire_terrier -> (correct) Rhodesian_ridgeback
# (predict) Great_dane -> (correct) Whippet
# (predict) Giant_schnauzer -> (correct) Standard_poodle
# (predict) American_staffordshire_terrier -> (correct) Rhodesian_ridgeback
# (predict) Chow -> (correct) Pekinese
# (predict) Scottish_deerhound -> (correct) Giant_schnauzer
# (predict) Old_english_sheepdog -> (correct) Irish_terrier
# (predict) Border_collie -> (correct) Collie
# (predict) Bull_mastiff -> (correct) Brabancon_griffon
# (predict) Rottweiler -> (correct) Miniature_pinscher
# (predict) West_highland_white_terrier -> (correct) Scotch_terrier
# (predict) Irish_wolfhound -> (correct) Scottish_deerhound
# (predict) Italian_greyhound -> (correct) Chihuahua
# (predict) Siberian_husky -> (correct) Eskimo_dog
# (predict) American_staffordshire_terrier -> (correct) Rhodesian_ridgeback
# (predict) Boston_bull -> (correct) French_bulldog
# (predict) Miniature_poodle -> (correct) Toy_poodle
# (predict) Shih-tzu -> (correct) Lhasa
# (predict) Redbone -> (correct) Rhodesian_ridgeback
# (predict) Saluki -> (correct) Whippet
# (predict) Kelpie -> (correct) Tibetan_mastiff
# (predict) Komondor -> (correct) West_highland_white_terrier
# (predict) Whippet -> (correct) Saluki
# (predict) Brabancon_griffon -> (correct) Toy_terrier
# (predict) Cardigan -> (correct) English_springer
# (predict) Greater_swiss_mountain_dog -> (correct) Entlebucher
# (predict) Dhole -> (correct) Dingo
# (predict) Yorkshire_terrier -> (correct) Australian_terrier
# (predict) Malamute -> (correct) Eskimo_dog
# (predict) Walker_hound -> (correct) Basset
# (predict) Shetland_sheepdog -> (correct) Collie
# (predict) Maltese_dog -> (correct) Pomeranian
# (predict) Siberian_husky -> (correct) Malamute
# (predict) Whippet -> (correct) Chesapeake_bay_retriever
# (predict) Kerry_blue_terrier -> (correct) Lakeland_terrier
# (predict) Tibetan_mastiff -> (correct) Leonberg
# (predict) Mexican_hairless -> (correct) Chihuahua
# (predict) German_shepherd -> (correct) African_hunting_dog
# (predict) Pembroke -> (correct) Cardigan
# (predict) Border_collie -> (correct) Collie
# (predict) Kerry_blue_terrier -> (correct) Bouvier_des_flandres
# (predict) Australian_terrier -> (correct) Silky_terrier
# (predict) Great_pyrenees -> (correct) Miniature_poodle
# (predict) Siberian_husky -> (correct) Eskimo_dog
# (predict) Shih-tzu -> (correct) Blenheim_spaniel
# (predict) Border_collie -> (correct) Shetland_sheepdog
# (predict) Vizsla -> (correct) Redbone
# (predict) Flat-coated_retriever -> (correct) Newfoundland
# (predict) Irish_wolfhound -> (correct) Norfolk_terrier
# (predict) Afghan_hound -> (correct) Siberian_husky
# (predict) Norwegian_elkhound -> (correct) Siberian_husky
# (predict) Irish_terrier -> (correct) Norwich_terrier
# (predict) Border_collie -> (correct) Shetland_sheepdog
# (predict) Briard -> (correct) Soft-coated_wheaten_terrier
# (predict) Collie -> (correct) Border_collie
# (predict) Toy_poodle -> (correct) Irish_water_spaniel
# (predict) African_hunting_dog -> (correct) English_springer
# (predict) Newfoundland -> (correct) Afghan_hound
# (predict) Boxer -> (correct) Rhodesian_ridgeback
# (predict) Dingo -> (correct) Whippet
# (predict) Weimaraner -> (correct) Pug
# (predict) Flat-coated_retriever -> (correct) Standard_poodle
# (predict) Tibetan_terrier -> (correct) English_setter
# (predict) Scottish_deerhound -> (correct) Irish_wolfhound
# (predict) West_highland_white_terrier -> (correct) Miniature_schnauzer
# (predict) Bull_mastiff -> (correct) Boxer
# (predict) Dingo -> (correct) Redbone
# (predict) Norwich_terrier -> (correct) Australian_terrier
# (predict) Irish_water_spaniel -> (correct) Cocker_spaniel
# (predict) Irish_setter -> (correct) Redbone
# (predict) West_highland_white_terrier -> (correct) Norfolk_terrier
# (predict) Greater_swiss_mountain_dog -> (correct) Black-and-tan_coonhound
# (predict) Groenendael -> (correct) Newfoundland
# (predict) Japanese_spaniel -> (correct) Papillon
# (predict) Toy_poodle -> (correct) Miniature_poodle
# (predict) Irish_wolfhound -> (correct) Norwich_terrier
# (predict) Tibetan_terrier -> (correct) Briard
# (predict) Tibetan_terrier -> (correct) Japanese_spaniel
# (predict) Bouvier_des_flandres -> (correct) Kerry_blue_terrier
# (predict) Cairn -> (correct) Border_terrier
# (predict) Siberian_husky -> (correct) Eskimo_dog
# (predict) Afghan_hound -> (correct) Bull_mastiff
# (predict) Pembroke -> (correct) Cardigan
# (predict) Norwich_terrier -> (correct) Soft-coated_wheaten_terrier
# (predict) Walker_hound -> (correct) Beagle
# (predict) Norfolk_terrier -> (correct) Miniature_schnauzer
# (predict) Schipperke -> (correct) Mexican_hairless
# (predict) Giant_schnauzer -> (correct) Briard
# (predict) Lhasa -> (correct) Tibetan_terrier
# (predict) Affenpinscher -> (correct) Standard_schnauzer
# (predict) Weimaraner -> (correct) Vizsla
# (predict) Rhodesian_ridgeback -> (correct) Dingo
# (predict) Italian_greyhound -> (correct) Boston_bull
# (predict) Irish_setter -> (correct) Golden_retriever
# (predict) Airedale -> (correct) Gordon_setter
# (predict) Rhodesian_ridgeback -> (correct) Redbone
# (predict) Basset -> (correct) Bloodhound
# (predict) Lakeland_terrier -> (correct) Airedale
# (predict) Giant_schnauzer -> (correct) Bouvier_des_flandres
# (predict) Silky_terrier -> (correct) Norwich_terrier
# (predict) Briard -> (correct) Australian_terrier
# (predict) Standard_schnauzer -> (correct) Miniature_schnauzer
# (predict) Walker_hound -> (correct) English_foxhound
# (predict) Appenzeller -> (correct) Greater_swiss_mountain_dog
# (predict) Airedale -> (correct) Wire-haired_fox_terrier
# (predict) Malinois -> (correct) Dingo
# (predict) Giant_schnauzer -> (correct) Bouvier_des_flandres
# (predict) Golden_retriever -> (correct) Sussex_spaniel
# (predict) Boston_bull -> (correct) French_bulldog
# (predict) Ibizan_hound -> (correct) Basenji
# (predict) Wire-haired_fox_terrier -> (correct) Kerry_blue_terrier
# (predict) Eskimo_dog -> (correct) Siberian_husky
# (predict) Appenzeller -> (correct) Entlebucher
# (predict) Pembroke -> (correct) Malamute
# (predict) Welsh_springer_spaniel -> (correct) Brittany_spaniel
# (predict) Australian_terrier -> (correct) Silky_terrier
# (predict) Walker_hound -> (correct) Basset
# (predict) Groenendael -> (correct) Flat-coated_retriever
# (predict) West_highland_white_terrier -> (correct) Soft-coated_wheaten_terrier
# (predict) Pekinese -> (correct) Brabancon_griffon
# (predict) Bernese_mountain_dog -> (correct) Greater_swiss_mountain_dog
# (predict) Newfoundland -> (correct) Groenendael
# (predict) Labrador_retriever -> (correct) Staffordshire_bullterrier
# (predict) Great_dane -> (correct) Scottish_deerhound
# (predict) French_bulldog -> (correct) Boston_bull
# (predict) Chesapeake_bay_retriever -> (correct) Labrador_retriever
# (predict) Beagle -> (correct) Walker_hound
# (predict) Toy_terrier -> (correct) Chihuahua
# (predict) Chihuahua -> (correct) Dingo
# (predict) Miniature_pinscher -> (correct) Toy_terrier
# (predict) American_staffordshire_terrier -> (correct) Staffordshire_bullterrier
# (predict) Italian_greyhound -> (correct) Redbone
# (predict) Irish_water_spaniel -> (correct) Chesapeake_bay_retriever
# (predict) Irish_terrier -> (correct) Norwich_terrier
# (predict) German_shepherd -> (correct) Beagle
# (predict) Toy_poodle -> (correct) Standard_poodle
# (predict) Lakeland_terrier -> (correct) Otterhound
# (predict) Pembroke -> (correct) Papillon
# (predict) American_staffordshire_terrier -> (correct) Staffordshire_bullterrier
# (predict) Newfoundland -> (correct) Briard
# (predict) Eskimo_dog -> (correct) Siberian_husky
# (predict) Maltese_dog -> (correct) Dandie_dinmont
# (predict) Samoyed -> (correct) Chow
# (predict) Shih-tzu -> (correct) Pekinese
# (predict) Miniature_pinscher -> (correct) Toy_terrier
# (predict) Flat-coated_retriever -> (correct) Pug
# (predict) Dhole -> (correct) African_hunting_dog
# (predict) Cocker_spaniel -> (correct) Golden_retriever
# (predict) Standard_poodle -> (correct) Miniature_poodle
# (predict) French_bulldog -> (correct) Staffordshire_bullterrier
# (predict) Entlebucher -> (correct) Greater_swiss_mountain_dog
# (predict) Dingo -> (correct) Malinois
# (predict) Italian_greyhound -> (correct) Chihuahua
# (predict) Toy_terrier -> (correct) Boston_bull
# (predict) Sealyham_terrier -> (correct) Borzoi
# (predict) Toy_poodle -> (correct) Miniature_poodle
# (predict) Redbone -> (correct) Rhodesian_ridgeback
# (predict) Siberian_husky -> (correct) Malamute
# (predict) Dingo -> (correct) Ibizan_hound
# (predict) Miniature_schnauzer -> (correct) Lhasa
# (predict) Weimaraner -> (correct) Great_dane
# (predict) Labrador_retriever -> (correct) Rottweiler
# (predict) English_foxhound -> (correct) Walker_hound
# (predict) Shih-tzu -> (correct) Lhasa
# (predict) Chow -> (correct) Newfoundland
# (predict) Bedlington_terrier -> (correct) English_setter
# (predict) Rhodesian_ridgeback -> (correct) Redbone
# (predict) Toy_terrier -> (correct) English_setter
# (predict) Boston_bull -> (correct) French_bulldog
# (predict) Borzoi -> (correct) Shetland_sheepdog
# (predict) Entlebucher -> (correct) Appenzeller
# (predict) Tibetan_terrier -> (correct) Lhasa
# (predict) Doberman -> (correct) Chesapeake_bay_retriever
# (predict) Japanese_spaniel -> (correct) Papillon
# (predict) Blenheim_spaniel -> (correct) Welsh_springer_spaniel
# (predict) Basenji -> (correct) American_staffordshire_terrier
# (predict) English_foxhound -> (correct) Basset
# (predict) Dingo -> (correct) Irish_setter
# (predict) English_setter -> (correct) German_short-haired_pointer
# (predict) Australian_terrier -> (correct) Yorkshire_terrier
# (predict) Silky_terrier -> (correct) Yorkshire_terrier
# (predict) Schipperke -> (correct) Standard_poodle
# (predict) Rhodesian_ridgeback -> (correct) Golden_retriever
# (predict) Pekinese -> (correct) Lhasa
# (predict) Cairn -> (correct) Briard
# (predict) Giant_schnauzer -> (correct) Newfoundland
# (predict) Australian_terrier -> (correct) Yorkshire_terrier
# (predict) Maltese_dog -> (correct) Soft-coated_wheaten_terrier
# (predict) Briard -> (correct) Irish_terrier
# (predict) Norwich_terrier -> (correct) Norfolk_terrier
# (predict) Silky_terrier -> (correct) Yorkshire_terrier
# (predict) Miniature_pinscher -> (correct) Rhodesian_ridgeback
# (predict) Eskimo_dog -> (correct) Malamute
# (predict) Shih-tzu -> (correct) Affenpinscher
# (predict) Boxer -> (correct) Blenheim_spaniel
# (predict) Blenheim_spaniel -> (correct) Japanese_spaniel
# (predict) German_short-haired_pointer -> (correct) Labrador_retriever
# (predict) Flat-coated_retriever -> (correct) Chesapeake_bay_retriever
# (predict) Toy_poodle -> (correct) Soft-coated_wheaten_terrier
# (predict) Standard_schnauzer -> (correct) Miniature_schnauzer
# (predict) Golden_retriever -> (correct) Labrador_retriever
# (predict) Collie -> (correct) Shetland_sheepdog
# (predict) Australian_terrier -> (correct) Yorkshire_terrier
# (predict) Australian_terrier -> (correct) Irish_terrier
# (predict) Border_collie -> (correct) Bernese_mountain_dog
# (predict) Toy_poodle -> (correct) Lakeland_terrier
# (predict) Leonberg -> (correct) German_shepherd
# (predict) Appenzeller -> (correct) Bernese_mountain_dog
# (predict) Vizsla -> (correct) Rhodesian_ridgeback
# (predict) Redbone -> (correct) Basset
# (predict) Kerry_blue_terrier -> (correct) Miniature_poodle
# (predict) Ibizan_hound -> (correct) Redbone
# (predict) Schipperke -> (correct) Groenendael
# (predict) Basenji -> (correct) Kelpie
# (predict) Scottish_deerhound -> (correct) Irish_wolfhound
# (predict) Beagle -> (correct) English_foxhound
# (predict) Papillon -> (correct) Shetland_sheepdog
# (predict) German_shepherd -> (correct) Norwegian_elkhound
# (predict) Staffordshire_bullterrier -> (correct) German_short-haired_pointer
# (predict) Flat-coated_retriever -> (correct) Irish_water_spaniel
# (predict) Miniature_poodle -> (correct) Toy_poodle
# (predict) Lhasa -> (correct) Shih-tzu
# (predict) Golden_retriever -> (correct) Irish_setter
# (predict) Appenzeller -> (correct) Entlebucher
# (predict) Norfolk_terrier -> (correct) Irish_terrier
# (predict) Vizsla -> (correct) Redbone
# (predict) Walker_hound -> (correct) Basset
# (predict) Shih-tzu -> (correct) French_bulldog
# (predict) Rottweiler -> (correct) Doberman
# (predict) Miniature_pinscher -> (correct) Chihuahua
# (predict) Lhasa -> (correct) Cairn
# (predict) Boxer -> (correct) Rhodesian_ridgeback
# (predict) Groenendael -> (correct) Newfoundland
# (predict) Pomeranian -> (correct) Pekinese
# (predict) Weimaraner -> (correct) Pug
# (predict) Vizsla -> (correct) Redbone
# (predict) Miniature_pinscher -> (correct) Brabancon_griffon
# (predict) Miniature_poodle -> (correct) Standard_poodle
# (predict) Doberman -> (correct) Giant_schnauzer
# (predict) Curly-coated_retriever -> (correct) Standard_poodle
# (predict) Kelpie -> (correct) Australian_terrier
# (predict) Kerry_blue_terrier -> (correct) Bouvier_des_flandres
# (predict) Boxer -> (correct) Bull_mastiff
# (predict) Irish_water_spaniel -> (correct) Bouvier_des_flandres
# (predict) Kuvasz -> (correct) Great_pyrenees
# (predict) Siberian_husky -> (correct) Eskimo_dog
# (predict) Shetland_sheepdog -> (correct) Collie
# (predict) Collie -> (correct) Shetland_sheepdog
# (predict) Standard_poodle -> (correct) Miniature_poodle
# (predict) English_foxhound -> (correct) Walker_hound
# (predict) Giant_schnauzer -> (correct) Bouvier_des_flandres
# (predict) English_foxhound -> (correct) Beagle
# (predict) Bernese_mountain_dog -> (correct) Appenzeller
# (predict) Siberian_husky -> (correct) Malamute
# (predict) Flat-coated_retriever -> (correct) Irish_setter
# (predict) Collie -> (correct) Golden_retriever
# (predict) Border_terrier -> (correct) Lakeland_terrier
# (predict) Whippet -> (correct) Eskimo_dog
# (predict) Lakeland_terrier -> (correct) Kerry_blue_terrier
# (predict) Toy_terrier -> (correct) Boston_bull
# (predict) Soft-coated_wheaten_terrier -> (correct) Bedlington_terrier
# (predict) Otterhound -> (correct) Miniature_schnauzer
# (predict) Australian_terrier -> (correct) Irish_terrier
# (predict) Irish_water_spaniel -> (correct) Chesapeake_bay_retriever
# (predict) Giant_schnauzer -> (correct) Bouvier_des_flandres
# (predict) Giant_schnauzer -> (correct) Tibetan_terrier
# (predict) Toy_poodle -> (correct) Standard_poodle
# (predict) Saluki -> (correct) Tibetan_mastiff
# (predict) Italian_greyhound -> (correct) Mexican_hairless
# (predict) Saluki -> (correct) Afghan_hound
# (predict) Dhole -> (correct) Pomeranian
# (predict) Dandie_dinmont -> (correct) Otterhound
# (predict) West_highland_white_terrier -> (correct) Scotch_terrier
# (predict) Basset -> (correct) Walker_hound
# (predict) Schipperke -> (correct) Flat-coated_retriever
# (predict) German_shepherd -> (correct) African_hunting_dog
# (predict) Blenheim_spaniel -> (correct) Welsh_springer_spaniel
# (predict) Yorkshire_terrier -> (correct) Silky_terrier
# (predict) Kuvasz -> (correct) Great_pyrenees
# (predict) Malinois -> (correct) Leonberg
# (predict) Bloodhound -> (correct) Beagle
# (predict) Beagle -> (correct) Walker_hound
# (predict) Basenji -> (correct) Ibizan_hound
# (predict) Cairn -> (correct) Norfolk_terrier
# (predict) Cairn -> (correct) Norwich_terrier
# (predict) Miniature_schnauzer -> (correct) Standard_schnauzer
# (predict) Borzoi -> (correct) Cardigan
# (predict) Irish_water_spaniel -> (correct) Miniature_poodle
# (predict) Collie -> (correct) Shetland_sheepdog
# (predict) Old_english_sheepdog -> (correct) Kuvasz
# (predict) Groenendael -> (correct) Norwegian_elkhound
# (predict) Otterhound -> (correct) Airedale
# (predict) Collie -> (correct) Border_collie
# (predict) Great_dane -> (correct) Bull_mastiff
# (predict) Lhasa -> (correct) Maltese_dog
# (predict) Silky_terrier -> (correct) Yorkshire_terrier
# (predict) Walker_hound -> (correct) Ibizan_hound
# (predict) Doberman -> (correct) Kelpie
# (predict) Walker_hound -> (correct) Beagle
# (predict) Miniature_pinscher -> (correct) Chihuahua
# (predict) Border_collie -> (correct) English_springer
# (predict) Standard_schnauzer -> (correct) Miniature_schnauzer
# (predict) Irish_terrier -> (correct) Toy_poodle
# (predict) Golden_retriever -> (correct) Cocker_spaniel
# (predict) Bull_mastiff -> (correct) Pug
# (predict) West_highland_white_terrier -> (correct) Scotch_terrier
# (predict) Lhasa -> (correct) Shih-tzu
# (predict) Tibetan_terrier -> (correct) Lhasa
# (predict) Lhasa -> (correct) Maltese_dog
# (predict) Italian_greyhound -> (correct) Great_pyrenees
# (predict) French_bulldog -> (correct) Pomeranian
# (predict) Irish_terrier -> (correct) Lakeland_terrier
# (predict) Miniature_pinscher -> (correct) Appenzeller
# (predict) Dandie_dinmont -> (correct) Cairn
# (predict) Beagle -> (correct) English_foxhound
# (predict) Miniature_pinscher -> (correct) Doberman
# (predict) Maltese_dog -> (correct) Clumber
# (predict) Border_terrier -> (correct) Cairn
# (predict) Toy_poodle -> (correct) Miniature_poodle
# (predict) English_springer -> (correct) English_setter
# (predict) Norwich_terrier -> (correct) Norfolk_terrier
# (predict) Norwich_terrier -> (correct) Australian_terrier
# (predict) Scottish_deerhound -> (correct) Scotch_terrier
# (predict) Ibizan_hound -> (correct) Whippet
# (predict) Border_collie -> (correct) Papillon
# (predict) Appenzeller -> (correct) Entlebucher
# (predict) Schipperke -> (correct) Groenendael
# (predict) Siberian_husky -> (correct) Malamute
# (predict) Miniature_poodle -> (correct) Toy_poodle
# (predict) Staffordshire_bullterrier -> (correct) Dingo
# (predict) Airedale -> (correct) English_setter
# (predict) Kerry_blue_terrier -> (correct) Affenpinscher
# (predict) Cardigan -> (correct) Pembroke
# (predict) Soft-coated_wheaten_terrier -> (correct) Norfolk_terrier
# (predict) American_staffordshire_terrier -> (correct) Staffordshire_bullterrier
# (predict) Australian_terrier -> (correct) Norwich_terrier
# (predict) Flat-coated_retriever -> (correct) Newfoundland
# (predict) Silky_terrier -> (correct) Australian_terrier
# (predict) Yorkshire_terrier -> (correct) Briard
# (predict) Doberman -> (correct) Black-and-tan_coonhound
# (predict) Yorkshire_terrier -> (correct) Australian_terrier
# (predict) Border_collie -> (correct) Tibetan_mastiff
# (predict) Norfolk_terrier -> (correct) Wire-haired_fox_terrier
# (predict) Beagle -> (correct) Siberian_husky
# (predict) Greater_swiss_mountain_dog -> (correct) Entlebucher
# (predict) German_shepherd -> (correct) Norwegian_elkhound
# (predict) Eskimo_dog -> (correct) Siberian_husky
# (predict) Maltese_dog -> (correct) Shih-tzu
# (predict) Norfolk_terrier -> (correct) Cairn
# (predict) Kerry_blue_terrier -> (correct) Irish_water_spaniel
# (predict) Greater_swiss_mountain_dog -> (correct) Appenzeller
# (predict) Ibizan_hound -> (correct) Whippet
# (predict) Yorkshire_terrier -> (correct) Silky_terrier
# (predict) Cairn -> (correct) Norfolk_terrier
# (predict) Kerry_blue_terrier -> (correct) Irish_water_spaniel
# (predict) Australian_terrier -> (correct) Silky_terrier
# (predict) Malamute -> (correct) Eskimo_dog
# (predict) Staffordshire_bullterrier -> (correct) Flat-coated_retriever
# (predict) American_staffordshire_terrier -> (correct) Boston_bull
# (predict) Dhole -> (correct) Brittany_spaniel
# (predict) Border_collie -> (correct) Shetland_sheepdog
# (predict) Collie -> (correct) Border_collie
# (predict) Italian_greyhound -> (correct) Staffordshire_bullterrier
# (predict) Boxer -> (correct) Rhodesian_ridgeback
# (predict) Miniature_schnauzer -> (correct) Bouvier_des_flandres
# (predict) Miniature_pinscher -> (correct) Appenzeller
# (predict) Golden_retriever -> (correct) Dingo
# (predict) Standard_schnauzer -> (correct) Giant_schnauzer
# (predict) Basenji -> (correct) Whippet
# (predict) Redbone -> (correct) Bloodhound
# (predict) Dingo -> (correct) Dhole
# (predict) Norwich_terrier -> (correct) Norfolk_terrier
# (predict) Bull_mastiff -> (correct) Rhodesian_ridgeback
# (predict) Miniature_pinscher -> (correct) Black-and-tan_coonhound
# (predict) Schipperke -> (correct) Collie
# correct =  1315  / not_correct =  477
# {'Affenpinscher': 11, 'Afghan_hound': 28, 'African_hunting_dog': 16, 'Airedale': 19, 'American_staffordshire_terrier': 12, 'Appenzeller': 14, 'Australian_terrier': 24, 'Basenji': 18, 'Basset': 16, 'Beagle': 14, 'Bedlington_terrier': 13, 'Bernese_mountain_dog': 26, 'Black-and-tan_coonhound': 9, 'Blenheim_spaniel': 21, 'Bloodhound': 12, 'Bluetick': 19, 'Border_collie': 14, 'Border_terrier': 16, 'Borzoi': 8, 'Boston_bull': 18, 'Bouvier_des_flandres': 18, 'Boxer': 6, 'Brabancon_griffon': 11, 'Briard': 13, 'Brittany_spaniel': 10, 'Bull_mastiff': 11, 'Cairn': 16, 'Cardigan': 10, 'Chesapeake_bay_retriever': 12, 'Chihuahua': 14, 'Chow': 17, 'Clumber': 21, 'Cocker_spaniel': 8, 'Collie': 12, 'Curly-coated_retriever': 5, 'Dandie_dinmont': 14, 'Dhole': 11, 'Dingo': 16, 'Doberman': 13, 'English_foxhound': 12, 'English_setter': 15, 'English_springer': 10, 'Entlebucher': 23, 'Eskimo_dog': 14, 'Flat-coated_retriever': 12, 'French_bulldog': 17, 'German_shepherd': 10, 'German_short-haired_pointer': 13, 'Giant_schnauzer': 17, 'Golden_retriever': 11, 'Gordon_setter': 11, 'Great_dane': 9, 'Great_pyrenees': 28, 'Greater_swiss_mountain_dog': 16, 'Groenendael': 14, 'Ibizan_hound': 20, 'Irish_setter': 15, 'Irish_terrier': 24, 'Irish_water_spaniel': 11, 'Irish_wolfhound': 15, 'Italian_greyhound': 20, 'Japanese_spaniel': 14, 'Keeshond': 18, 'Kelpie': 8, 'Kerry_blue_terrier': 16, 'Komondor': 10, 'Kuvasz': 14, 'Labrador_retriever': 15, 'Lakeland_terrier': 17, 'Leonberg': 16, 'Lhasa': 16, 'Malamute': 19, 'Malinois': 9, 'Maltese_dog': 21, 'Mexican_hairless': 15, 'Miniature_pinscher': 16, 'Miniature_poodle': 14, 'Miniature_schnauzer': 14, 'Newfoundland': 15, 'Norfolk_terrier': 17, 'Norwegian_elkhound': 16, 'Norwich_terrier': 16, 'Old_english_sheepdog': 11, 'Otterhound': 10, 'Papillon': 16, 'Pekinese': 13, 'Pembroke': 16, 'Pomeranian': 17,
': 0.75, 'Irish_water_spaniel': 0.6363636363636364, 'Irish_wolfhound': 0.8666666666666667, 'Italian_greyhound': 1.0, 'Japanese_spaniel': 0.8571428571428571, 'Keeshond': 1.0, 'Kelpie': 0.625, 'Kerry_blue_terrier': 0.8125, 'Komondor': 1.0, 'Kuvasz': 0.8571428571428571, 'Labrador_retriever': 0.6666666666666666, 'Lakeland_terrier': 0.7058823529411765, 'Leonberg': 0.8125, 'Lhasa': 0.5, 'Malamute': 0.631578947368421, 'Malinois': 0.8888888888888888, 'Maltese_dog': 0.9047619047619048, 'Mexican_hairless': 0.6666666666666666, 'Miniature_pinscher': 0.8125, 'Miniature_poodle': 0.42857142857142855, 'Miniature_schnauzer': 0.5, 'Newfoundland': 0.6, 'Norfolk_terrier': 0.35294117647058826, 'Norwegian_elkhound': 0.8125, 'Norwich_terrier': 0.625, 'Old_english_sheepdog': 1.0, 'Otterhound': 0.6, 'Papillon': 0.75, 'Pekinese': 0.7692307692307693, 'Pembroke': 0.9375, 'Pomeranian': 0.8235294117647058, 'Pug': 0.75, 'Redbone': 0.5, 'Rhodesian_ridgeback': 0.4, 'Rottweiler': 0.9166666666666666, 'Saint_bernard': 0.9565217391304348, 'Saluki': 0.9411764705882353, 'Samoyed': 1.0, 'Schipperke': 0.9473684210526315, 'Scotch_terrier': 0.6923076923076923, 'Scottish_deerhound': 0.9230769230769231, 'Sealyham_terrier': 0.8666666666666667, 'Shetland_sheepdog': 0.5555555555555556, 'Shih-tzu': 0.7647058823529411, 'Siberian_husky': 0.5294117647058824, 'Silky_terrier': 0.6, 'Soft-coated_wheaten_terrier': 0.6666666666666666, 'Staffordshire_bullterrier': 0.3076923076923077, 'Standard_poodle': 0.23076923076923078, 'Standard_schnauzer': 0.5833333333333334, 'Sussex_spaniel': 0.9285714285714286, 'Tibetan_mastiff': 0.7857142857142857, 'Tibetan_terrier': 0.75, 'Toy_poodle': 0.6428571428571429, 'Toy_terrier': 0.6153846153846154, 'Vizsla': 0.7142857142857143, 'Walker_hound': 0.5, 'Weimaraner': 1.0, 'Welsh_springer_spaniel': 0.875, 'West_highland_white_terrier': 0.9285714285714286, 'Whippet': 0.4, 'Wire-haired_fox_terrier': 0.7692307692307693, 'Yorkshire_terrier': 0.4166666666666667}
# <BarContainer object of 120 artists>

# %%
test_transform = transforms.Compose([transforms.Resize((256,256)),
                                     transforms.CenterCrop((224,224)),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.476, 0.440, 0.384], [0.229, 0.224, 0.220])])

test_data = TestDataset(root='./test', transform=test_transform)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

# %%
def test(model, test_loader, device):
    preds = None
    model.eval()
    with torch.no_grad():
        for data in test_loader:
            data = data.to(device)
            pred = model(data)
            if preds is None:
                preds = pred.argmax(1)
            else:
                preds = torch.cat([preds, pred.argmax(1)], dim=0)
    return preds

# %%
preds = test(model, test_loader, device)
submission = pd.read_csv('sample_submission.csv')
submission['Category'] = preds.cpu().numpy()
submission.to_csv('drive/MyDrive/dcompetition/submission4.csv', index=False)
